# %% [markdown]
# <a href="https://colab.research.google.com/github/ak9250/taming-transformers/blob/master/tamingtransformerscolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/CompVis/taming-transformers.git

# %%
cd taming-transformers/

# %%
mkdir logs

# %%
cd logs

# %%
mkdir 2020-11-09T13-31-51_sflckr/

# %%
cd 2020-11-09T13-31-51_sflckr/

# %%
mkdir checkpoints

# %%
cd checkpoints/

# %%
# !gdown https://drive.google.com/uc?id=1XZVQmiru3Cg6R0r2SzdoUJnb9juuAZNE

# %%
cd ..

# %%
# !gdown https://drive.google.com/uc?id=1QaYtO0CWdoeAeY5CSm9-VK8VPFV0ijfv

# %%
# !unzip configs.zip

# %%
cd /content/taming-transformers/

# %%
# %%writefile requirements.txt
# albumentations==0.4.3
# pudb==2019.2
# imageio==2.9.0
# imageio-ffmpeg==0.4.2
# omegaconf==2.0.0
# test-tube>=0.7.5
# pytorch-lightning==1.0.8
# streamlit>=0.73.1
# -e .

# %%
# !pip install -r requirements.txt

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip

# %%
# !unzip ngrok-stable-linux-amd64.zip

# %%
get_ipython().system_raw('./ngrok http 8501 &')

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    'import sys, json; print("Execute the next cell and the go to the following URL: " +json.load(sys.stdin)["tunnels"][0]["public_url"])'

# %%
# !streamlit run scripts/sample_conditional.py -- -r logs/2020-11-09T13-31-51_sflckr/
